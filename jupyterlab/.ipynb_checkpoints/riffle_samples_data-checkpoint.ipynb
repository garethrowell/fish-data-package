# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = r"C:\Users\GRowell\HTLN-data-packages-data\aqinvert\RiffleSamplesData.csv"
df = pd.read_csv(file)
print(df.head())
# Out:
#                                    ParkName ParkCode  Season      LocationID  \
# 0  Ozark National Scenic Riverways - RIVERS     OZAR    2005  OZARRMINVECM01
# 1  Ozark National Scenic Riverways - RIVERS     OZAR    2005  OZARRMINVECM01
# 2  Ozark National Scenic Riverways - RIVERS     OZAR    2005  OZARRMINVECM01
# 3  Ozark National Scenic Riverways - RIVERS     OZAR    2005  OZARRMINVECM01
# 4  Ozark National Scenic Riverways - RIVERS     OZAR    2005  OZARRMINVECM01
#
#                EventID  RiffleNo Replicate  Width_m  Depth_cm  Velocity_ms  \
# 0  OZARRMINVE2006JAN03         2         L     10.5        22         0.56
# 1  OZARRMINVE2006JAN03         2         M     13.0        28         0.76
# 2  OZARRMINVE2006JAN03         2         R     21.0        20         0.26
# 3  OZARRMINVE2006JAN03         3         L     13.0        20         0.62
# 4  OZARRMINVE2006JAN03         3         M     15.5        28         0.50
#
# ...

# %%
df.dtypes
# Out:
# ParkName             object
# ParkCode             object
# Season                int64
# LocationID           object
# EventID              object
# RiffleNo              int64
# Replicate            object
# Width_m             float64
# Depth_cm              int64
# Velocity_ms         float64
# Substrate             int64
# Substrate_mm        float64
# Embeddedness          int64
# Embeddedness_pct    float64
# Vegetation            int64
# Vegetation_pct      float64
# Algae                 int64
# Algae_pct           float64
# Periphyton            int64
# Periphyton_pct      float64
# Deposition            int64
# Deposition_pct      float64
# Organic               int64
# Organic_pct         float64
# dtype: object

# %%
sorted(df['ParkName'].unique())
# Out:
# ['Buffalo National River',
#  'Effigy Mounds National Monument',
#  'George Washington Carver National Monument',
#  'Herbert Hoover National Historic Site',
#  'Hot Springs National Park',
#  'Ozark National Scenic Riverways - RIVERS',
#  'Pea Ridge National Military Park',
#  'Pipestone National Monument',
#  'Tallgrass Prairie National Preserve',
#  'Wilsons Creek National Battlefield']

# %%
sorted(df['ParkCode'].unique())
# Out:
# ['BUFF',
#  'EFMO',
#  'GWCA',
#  'HEHO',
#  'HOSP',
#  'OZAR',
#  'PERI',
#  'PIPE',
#  'TAPR',
#  'WICR']

# %%
df['Season'].unique()
# Out:
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024])

# %%
sorted(df["LocationID"].unique())
# Out:
# ['BUFFRMINVEBM01',
#  'BUFFRMINVEBM02',
#  'BUFFRMINVEBM03',
#  'BUFFRMINVEBM04',
#  'BUFFRMINVEBM05',
#  'BUFFRMINVEBM06',
#  'BUFFRMINVEBT01',
#  'BUFFRMINVEBT03',
#  'BUFFRMINVEBT04',
#  'BUFFRMINVEBT05',
#  'BUFFRMINVEBT06',
#  'BUFFRMINVEBT07',
#  'BUFFRMINVEBT08',
#  'BUFFRMINVEBT09',
#  'BUFFRMINVEBT10',
#  'BUFFRMINVEBT11',
#  'BUFFRMINVEBT13',
#  'BUFFRMINVEBT14',
#  'BUFFRMINVEBT15',
#  'BUFFRMINVEBT16',
#  'BUFFRMINVEBT17',
#  'BUFFRMINVEBT19',
#  'BUFFRMINVEBT20',
#  'BUFFRMINVEBT22',
#  'BUFFRMINVEBT23',
#  'BUFFRMINVEBT24',
#  'BUFFRMINVEBT25',
#  'BUFFRMINVEBT27',
#  'BUFFRMINVEBT30',
#  'BUFFRMINVEBT31',
#  'BUFFRMINVEBT33',
#  'EFMOAqubug01',
#  'GWCAAquBug01',
#  'GWCAAquBug02',
#  'GWCAAquBug03',
#  'HEHOAqubug01',
#  'HOSPAqubug01',
#  'HOSPAqubug02',
#  'OZARRMINVECM01',
#  'OZARRMINVECM02',
#  'OZARRMINVECM03',
#  'OZARRMINVECM04',
#  'OZARRMINVECM05',
#  'OZARRMINVECM06',
#  'OZARRMINVECT01',
#  'OZARRMINVECT02',
#  'OZARRMINVECT03',
#  'OZARRMINVECT04',
# ...

# %%
sorted(df['EventID'].unique())
# Out:
# ['BUFFRMINVE2005DEC01',
#  'BUFFRMINVE2005DEC14',
#  'BUFFRMINVE2005DEC20',
#  'BUFFRMINVE2005NOV29',
#  'BUFFRMINVE2005NOV30',
#  'BUFFRMINVE2007Dec03',
#  'BUFFRMINVE2007Dec04',
#  'BUFFRMINVE2007FEB09',
#  'BUFFRMINVE2007FEB20',
#  'BUFFRMINVE2007FEB21',
#  'BUFFRMINVE2007FEB22',
#  'BUFFRMINVE2007JAN04',
#  'BUFFRMINVE2007JAN05',
#  'BUFFRMINVE2007JAN08',
#  'BUFFRMINVE2007JAN09',
#  'BUFFRMINVE2007Nov26',
#  'BUFFRMINVE2007Nov27',
#  'BUFFRMINVE2007Nov28',
#  'BUFFRMINVE2007Nov29',
#  'BUFFRMINVE2007Nov30',
#  'BUFFRMINVE2008Dec02',
#  'BUFFRMINVE2008Dec03',
#  'BUFFRMINVE2008Dec04',
#  'BUFFRMINVE2008Dec05',
#  'BUFFRMINVE2008Dec10',
#  'BUFFRMINVE2008Dec11',
#  'BUFFRMINVE2008Jan22',
#  'BUFFRMINVE2008Jan23',
#  'BUFFRMINVE2009Dec07',
#  'BUFFRMINVE2009Dec08',
#  'BUFFRMINVE2009Dec14',
#  'BUFFRMINVE2009Dec15',
#  'BUFFRMINVE2009Dec16',
#  'BUFFRMINVE2009Feb18',
#  'BUFFRMINVE2009Jan08',
#  'BUFFRMINVE2010Dec01',
#  'BUFFRMINVE2010Jan11',
#  'BUFFRMINVE2010Jan12',
# ...

# %%
df['RiffleNo'].unique()
# Out:
# array([2, 3, 1])

# %%
df['Replicate'].unique()
# Out:
# array(['L', 'M', 'R'], dtype=object)

# %%
col = ['Width_m'] 
df2 = df[df[col] > 0]
df2.hist(column='Width_m')
# Out:
# array([[<Axes: title={'center': 'Width_m'}>]], dtype=object)

# %%
col = ['Depth_cm'] 
df2 = df[df[col] > 0]
df2.hist(column='Depth_cm')
# Out:
# array([[<Axes: title={'center': 'Depth_cm'}>]], dtype=object)

# %%
col = ['Velocity_ms'] 
df2 = df[df[col] > 0]
df2.hist(column='Velocity_ms')
# Out:
# array([[<Axes: title={'center': 'Velocity_ms'}>]], dtype=object)

# %%
df['Substrate'].unique()
# Out:
# array([13, 12, 14, 15, 16,  9,  8, 10,  7, 19, 18, 17, 11,  3,  5, 21,  1,
#        20, 24])

# %%
col = ['Substrate'] 
df2 = df[df[col] > 0]
df2.hist(column='Substrate')
# Out:
# array([[<Axes: title={'center': 'Substrate'}>]], dtype=object)

# %%
col = ['Substrate_mm'] 
df2 = df[(df[col] > 0) & (df[col] < 100)]
df2.hist(column='Substrate_mm')
# Out:
# array([[<Axes: title={'center': 'Substrate_mm'}>]], dtype=object)

# %%
col = ['Substrate_mm'] 
df2 = df[(df[col] > 100) & (df[col] < 1000)]
df2.hist(column='Substrate_mm')
# Out:
# array([[<Axes: title={'center': 'Substrate_mm'}>]], dtype=object)

# %%
# Outlier - single value at 10,000
col = ['Substrate_mm'] 
df2 = df[(df[col] > 1000)]
df2.hist(column='Substrate_mm')
# Out:
# array([[<Axes: title={'center': 'Substrate_mm'}>]], dtype=object)

# %%
col = ['Embeddedness'] 
df2 = df[df[col] > 0]
df2.hist(column='Embeddedness')
# Out:
# array([[<Axes: title={'center': 'Embeddedness'}>]], dtype=object)

# %%
col = ['Embeddedness_pct'] 
df2 = df[df[col] > 0]
df2.hist(column='Embeddedness_pct')
# Out:
# array([[<Axes: title={'center': 'Embeddedness_pct'}>]], dtype=object)

# %%
col = ['Vegetation'] 
df2 = df[df[col] > 0]
df2.hist(column='Vegetation')
# Out:
# array([[<Axes: title={'center': 'Vegetation'}>]], dtype=object)

# %%
col = ['Vegetation_pct'] 
df2 = df[df[col] > 0]
df2.hist(column='Vegetation_pct')
# Out:
# array([[<Axes: title={'center': 'Vegetation_pct'}>]], dtype=object)

# %%
col = ['Algae'] 
df2 = df[df[col] > 0]
df2.hist(column='Algae')
# Out:
# array([[<Axes: title={'center': 'Algae'}>]], dtype=object)

# %%
col = ['Algae_pct'] 
df2 = df[df[col] > 0]
df2.hist(column='Algae_pct')
# Out:
# array([[<Axes: title={'center': 'Algae_pct'}>]], dtype=object)

# %%
col = ['Periphyton'] 
df2 = df[df[col] > 0]
df2.hist(column='Periphyton')
# Out:
# array([[<Axes: title={'center': 'Periphyton'}>]], dtype=object)

# %%
col = ['Periphyton_pct'] 
df2 = df[df[col] > 0]
df2.hist(column='Periphyton_pct')
# Out:
# array([[<Axes: title={'center': 'Periphyton_pct'}>]], dtype=object)

# %%
col = ['Deposition'] 
df2 = df[df[col] > 0]
df2.hist(column='Deposition')
# Out:
# array([[<Axes: title={'center': 'Deposition'}>]], dtype=object)

# %%
col = ['Deposition_pct'] 
df2 = df[df[col] > 0]
df2.hist(column='Deposition_pct')
# Out:
# array([[<Axes: title={'center': 'Deposition_pct'}>]], dtype=object)

# %%
col = ['Organic'] 
df2 = df[df[col] > 0]
df2.hist(column='Organic')
# Out:
# array([[<Axes: title={'center': 'Organic'}>]], dtype=object)

# %%
col = ['Organic_pct'] 
df2 = df[df[col] > 0]
df2.hist(column='Organic_pct')
# Out:
# array([[<Axes: title={'center': 'Organic_pct'}>]], dtype=object)
