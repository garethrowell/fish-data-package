# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\GRowell\fish-data\raw_data\HTLN_Fish_CrossSectionalInfo_SE.csv"
df = pd.read_csv(path)
print(df.head())
# Out:
#    Season         LocationID              EventID  SiteNumber ChannelType  \
# 0    2001  PIPEShiner01above  PIPEShiner2001Sep12           1        main
# 1    2001  PIPEShiner01above  PIPEShiner2001Sep12           1        main
# 2    2001  PIPEShiner01above  PIPEShiner2001Sep12           1        main
# 3    2001  PIPEShiner01above  PIPEShiner2001Sep12           2        main
# 4    2001  PIPEShiner01above  PIPEShiner2001Sep12           2        main
#
#    TransectNumber SampleLocation ChannelUnit  PoolForm  Width_m  Depth_cm  \
# 0               1              M          PO       NaN      3.9      21.0
# 1               2              M          PO       NaN      NaN       NaN
# 2               3              M          PO       NaN      NaN       NaN
# 3               1              M          PO       NaN      3.8      15.0
# 4               2              M          PO       NaN      NaN       NaN
#
#    Velocity_ms Comment
# 0          NaN     NaN
# 1          NaN     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN

# %%
df.dtypes
# Out:
# Season              int64
# LocationID         object
# EventID            object
# SiteNumber          int64
# ChannelType        object
# TransectNumber      int64
# SampleLocation     object
# ChannelUnit        object
# PoolForm          float64
# Width_m           float64
# Depth_cm          float64
# Velocity_ms       float64
# Comment            object
# dtype: object

# %%
sorted(df['Season'].unique())
# Out:
# [np.int64(2001),
#  np.int64(2002),
#  np.int64(2003),
#  np.int64(2004),
#  np.int64(2005),
#  np.int64(2006),
#  np.int64(2007),
#  np.int64(2008),
#  np.int64(2009),
#  np.int64(2010),
#  np.int64(2011),
#  np.int64(2013),
#  np.int64(2014),
#  np.int64(2015),
#  np.int64(2016),
#  np.int64(2017),
#  np.int64(2018),
#  np.int64(2019),
#  np.int64(2021),
#  np.int64(2022),
#  np.int64(2023),
#  np.int64(2024)]

# %%
sorted(df['LocationID'].unique())
# Out:
# ['HOMEShiner01lower',
#  'HOMEShiner01upper',
#  'PIPEShiner01above',
#  'PIPEShiner01lower',
#  'PIPEShiner01middl',
#  'PIPEShiner01upper',
#  'TAPRShiner01lower',
#  'TAPRShiner01middl',
#  'TAPRShiner01upper',
#  'TAPRShiner02lower',
#  'TAPRShiner02middl',
#  'TAPRShiner04middl',
#  'TAPRShiner05middl',
#  'TAPRShiner10middl',
#  'TAPRShiner10upper',
#  'TAPRShiner12middl',
#  'TAPRShiner17lower',
#  'TAPRShiner17upper',
#  'TAPRShiner18middl',
#  'TAPRShiner22lower',
#  'TAPRShiner22ltupp',
#  'TAPRShiner22rtupp',
#  'TAPRShiner23middl',
#  'TAPRShiner24lower',
#  'TAPRShiner24middl',
#  'TAPRShiner34lower',
#  'TAPRShiner35lower',
#  'TAPRShiner36middl',
#  'TAPRShiner36upper']

# %%
sorted(df['EventID'].unique())
# Out:
# ['HOMEShiner2004Sep13',
#  'HOMEShiner2006Aug31',
#  'HOMEShiner2008Aug27',
#  'HOMEShiner2011Sep20',
#  'HOMEShiner2015Sep03',
#  'HOMEShiner2017Sep07',
#  'HOMEShiner2023Sep07',
#  'PIPEShiner2001Sep11',
#  'PIPEShiner2001Sep12',
#  'PIPEShiner2002Sep17',
#  'PIPEShiner2003Sep04',
#  'PIPEShiner2004Sep16',
#  'PIPEShiner2005Sep20',
#  'PIPEShiner2006Aug29',
#  'PIPEShiner2006Aug30',
#  'PIPEShiner2007Aug28',
#  'PIPEShiner2008Aug26',
#  'PIPEShiner2009Aug25',
#  'PIPEShiner2010Aug31',
#  'PIPEShiner2011Aug31',
#  'PIPEShiner2013Sep13',
#  'PIPEShiner2013Sep14',
#  'PIPEShiner2016Sep10',
#  'PIPEShiner2018Sep08',
#  'PIPEShiner2021Aug26',
#  'PIPEShiner2022Aug18',
#  'PIPEShiner2023Aug29',
#  'PIPEShiner2024Aug20',
#  'TAPRShiner2001Aug28',
#  'TAPRShiner2001Aug29',
#  'TAPRShiner2001Aug30',
#  'TAPRShiner2001Aug31',
#  'TAPRShiner2001Oct09',
#  'TAPRShiner2001Oct10',
#  'TAPRShiner2001Oct11',
#  'TAPRShiner2001Oct12',
#  'TAPRShiner2001Oct13',
#  'TAPRShiner2002Oct01',
#  'TAPRShiner2002Oct02',
#  'TAPRShiner2002Oct03',
#  'TAPRShiner2002Oct04',
#  'TAPRShiner2002Oct05',
#  'TAPRShiner2003Oct06',
#  'TAPRShiner2003Oct07',
#  'TAPRShiner2003Oct08',
#  'TAPRShiner2003Oct09',
#  'TAPRShiner2004Oct04',
#  'TAPRShiner2004Oct05',
#  'TAPRShiner2004Oct06',
#  'TAPRShiner2004Oct07',
#  'TAPRShiner2005Oct03',
#  'TAPRShiner2005Oct04',
#  'TAPRShiner2005Oct05',
#  'TAPRShiner2006Sep18',
#  'TAPRShiner2006Sep19',
#  'TAPRShiner2006Sep20',
#  'TAPRShiner2007Sep09',
#  'TAPRShiner2007Sep10',
#  'TAPRShiner2007Sep11',
#  'TAPRShiner2007Sep12',
#  'TAPRShiner2007Sep13',
#  'TAPRShiner2008Sep07',
#  'TAPRShiner2008Sep08',
#  'TAPRShiner2008Sep09',
#  'TAPRShiner2008Sep10',
#  'TAPRShiner2009Sep08',
#  'TAPRShiner2009Sep09',
#  'TAPRShiner2009Sep10',
#  'TAPRShiner2009Sep11',
#  'TAPRShiner2010Sep07',
#  'TAPRShiner2010Sep08',
#  'TAPRShiner2013Sep18',
#  'TAPRShiner2013Sep19',
#  'TAPRShiner2014Sep09',
#  'TAPRShiner2014Sep10',
#  'TAPRShiner2015Aug30',
#  'TAPRShiner2015Aug31',
#  'TAPRShiner2015Sep01',
#  'TAPRShiner2015Sep02',
#  'TAPRShiner2016Sep01',
#  'TAPRShiner2016Sep02',
#  'TAPRShiner2017Sep05',
#  'TAPRShiner2017Sep06',
#  'TAPRShiner2018Sep04',
#  'TAPRShiner2018Sep05',
#  'TAPRShiner2018Sep06',
#  'TAPRShiner2018Sep07',
#  'TAPRShiner2019Sep10',
#  'TAPRShiner2019Sep11',
#  'TAPRShiner2021Sep07',
#  'TAPRShiner2021Sep08',
#  'TAPRShiner2021Sep09',
#  'TAPRShiner2021Sep10',
#  'TAPRShiner2022Aug16',
#  'TAPRShiner2022Aug17',
#  'TAPRShiner2024Aug12',
#  'TAPRShiner2024Aug13',
#  'TAPRShiner2024Aug14',
#  'TAPRShiner2024Aug15',
#  'TAPRShiner2024Aug16']

# %%
df.dtypes
# Out:
# Season              int64
# LocationID         object
# EventID            object
# SiteNumber          int64
# ChannelType        object
# TransectNumber      int64
# SampleLocation     object
# ChannelUnit        object
# PoolForm           object
# Width_m           float64
# Depth_cm          float64
# Velocity_ms       float64
# Comment            object
# dtype: object

# %%
sorted(df["SiteNumber"].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\miniforge3\envs\pydata-book\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SiteNo'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sorted(df["SiteNo"].unique())
#
# File ~\AppData\Local\miniforge3\envs\pydata-book\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\miniforge3\envs\pydata-book\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'SiteNo'

# %%
sorted(df["ChannelType"].unique())
# Out:
# ['main']

# %%
sorted(df["TransectNumber"].unique())
# Out:
# [np.int64(1), np.int64(2), np.int64(3)]

# %%
sorted(df["SampleLocation"].unique())
# Out:
# ['M']

# %%
sorted(df["ChannelUnit"].unique())
# Out:
# ['GL', 'PO', 'RI', 'RRX', 'RU']

# %%
df["PoolForm"] = df["PoolForm"].astype(str)
sorted(df["PoolForm"].unique())
# Out:
# ['nan']

# %%
cols = ['Width_m'] 
df2 = df[(df[cols] > 0) & (df[cols] <= 200)]
df2.hist(column='Width_m')
# Out:
# array([[<Axes: title={'center': 'Width_m'}>]], dtype=object)

# %%
cols = ['Depth_cm'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='Depth_cm')
# Out:
# array([[<Axes: title={'center': 'Depth_cm'}>]], dtype=object)

# %%
cols = ['Velocity_ms'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='Velocity_ms')
# Out:
# array([[<Axes: title={'center': 'Velocity_ms'}>]], dtype=object)

# %%
df.dtypes
# Out:
# Season              int64
# LocationID         object
# EventID            object
# SiteNumber          int64
# ChannelType        object
# TransectNumber      int64
# SampleLocation     object
# ChannelUnit        object
# PoolForm           object
# Width_m           float64
# Depth_cm          float64
# Velocity_ms       float64
# Comment            object
# dtype: object

# %%
sorted(df["DomSubstrate"].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\miniforge3\envs\pydata-book\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DomSubstrate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sorted(df["DomSubstrate"].unique())
#
# File ~\AppData\Local\miniforge3\envs\pydata-book\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\miniforge3\envs\pydata-book\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'DomSubstrate'

# %%
cols = ['DomSubstrate'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='DomSubstrate')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 cols = ['DomSubstrate']
# ----> 2 df2 = df[(df[cols] > 0)]
#       3 df2.hist(column='DomSubstrate')
#
# File ~\AppData\Local\miniforge3\envs\pydata-book\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\miniforge3\envs\pydata-book\lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\miniforge3\envs\pydata-book\lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['DomSubstrate'], dtype='object')] are in the [columns]"

# %%
cols = ['DomSubstrateMidpoint'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='DomSubstrateMidpoint')
# Out:
# array([[<Axes: title={'center': 'DomSubstrateMidpoint'}>]], dtype=object)

# %%
cols = ['Embeddedness'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='Embeddedness')
# Out:
# array([[<Axes: title={'center': 'Embeddedness'}>]], dtype=object)

# %%
cols = ['EmbeddednessMidpoint'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='EmbeddednessMidpoint')
# Out:
# array([[<Axes: title={'center': 'EmbeddednessMidpoint'}>]], dtype=object)

# %%
cols = ['CanopyCover'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='CanopyCover')
# Out:
# array([[<Axes: title={'center': 'CanopyCover'}>]], dtype=object)

# %%
cols = ['CanopyCoverMidpoint'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='CanopyCoverMidpoint')
# Out:
# array([[<Axes: title={'center': 'CanopyCoverMidpoint'}>]], dtype=object)

# %%
df["Comment"] = df["Comment"].astype(str)
sorted(df["Comment"].unique())
# Out:
# ['> 200 m deep',
#  '> 200cm deep',
#  'Big Spring extra sample - Partial habitat data collected on vegetation transects only',
#  'Bridge Construction',
#  'Bridge construction',
#  'Downstream',
#  'Flow too high',
#  'Greater than 200 cm depth',
#  'Lower BW (River Left)',
#  'Only wetted width - islands excluded',
#  'Over 200 cm depth',
#  'River left',
#  'River right',
#  'Too deep to sample',
#  'Upper BW (River Right)',
#  'Upstream',
#  'depth > 200 cm',
#  'depth > 200cm',
#  'depth >100cm',
#  'depth >200 cm',
#  'depth>200cm',
#  'end of sample reach',
#  'lower backwater',
#  'nan',
#  'no canopy cover data',
#  'too deep',
#  'too fast',
#  'transect ended at 534m',
#  'upper backwater']
