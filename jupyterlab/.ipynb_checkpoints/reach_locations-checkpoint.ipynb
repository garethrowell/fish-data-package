# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\GRowell\fish-data\raw_data\HTLN_Fish_Reaches_Locations.csv"
df = pd.read_csv(path)
print(df.head())
# Out:
#    ReachID InvertLocationID  FishLocationID ParkCode                ParkName  \
# 0  BUFFM01   BUFFRMINVEBM01  BUFFRMFISHBM01     BUFF  Buffalo National River
# 1  BUFFM02   BUFFRMINVEBM02  BUFFRMFISHBM02     BUFF  Buffalo National River
# 2  BUFFM03   BUFFRMINVEBM03  BUFFRMFISHBM03     BUFF  Buffalo National River
# 3  BUFFM04   BUFFRMINVEBM04  BUFFRMFISHBM04     BUFF  Buffalo National River
# 4  BUFFM05   BUFFRMINVEBM05  BUFFRMFISHBM05     BUFF  Buffalo National River
#
#    Latitude  Longitude Notes
# 0    35.974    -93.397   NaN
# 1    36.037    -93.105   NaN
# 2    36.000    -93.006   NaN
# 3    35.983    -92.778   NaN
# 4    36.011    -92.682   NaN

# %%
df.dtypes
# Out:
# ReachID              object
# InvertLocationID     object
# FishLocationID       object
# ParkCode             object
# ParkName             object
# Latitude            float64
# Longitude           float64
# Notes                object
# dtype: object

# %%
sorted(df['ReachID'].unique())
# Out:
# ['BUFFM01',
#  'BUFFM02',
#  'BUFFM03',
#  'BUFFM04',
#  'BUFFM05',
#  'BUFFM06',
#  'BUFFT01',
#  'BUFFT04',
#  'BUFFT05',
#  'BUFFT06',
#  'BUFFT07',
#  'BUFFT08',
#  'BUFFT09',
#  'BUFFT10',
#  'BUFFT11',
#  'BUFFT12',
#  'BUFFT13',
#  'BUFFT14',
#  'BUFFT15',
#  'BUFFT16',
#  'BUFFT17',
#  'BUFFT20',
#  'BUFFT21',
#  'BUFFT22',
#  'BUFFT23',
#  'BUFFT24',
#  'BUFFT25',
#  'BUFFT28',
#  'BUFFT29',
#  'BUFFT30',
#  'BUFFT31',
#  'BUFFT32',
#  'BUFFT33',
#  'CURRM01',
#  'CURRM02',
#  'CURRM03',
#  'CURRM04',
#  'CURRM05',
#  'CURRM06',
#  'CURRT01',
#  'CURRT02',
#  'CURRT03',
#  'CURRT04',
#  'CURRT07',
#  'CURRT08',
#  'CURRT11',
#  'CURRT12',
#  'CURRT13',
#  'CURRT14',
#  'CURRT15',
#  'CURRT16',
#  'EFMOUPP01',
#  'GWCALOW01',
#  'GWCALOW02',
#  'GWCALOW03',
#  'HEHOLOW01',
#  'HOMELOW01',
#  'HOMEUPP01',
#  'HOSPLOW01',
#  'HOSPLOW02',
#  'JACKM01',
#  'JACKM02',
#  'JACKM03',
#  'JACKT01',
#  'JACKT02',
#  'JACKT03',
#  'OZARSPRALL',
#  'OZARSPRBIG',
#  'OZARSPRBLU',
# ...

# %%
df["InvertLocationID"] = df["InvertLocationID"].astype(str)
sorted(df["InvertLocationID"].unique())
# Out:
# ['BUFFRMINVEBM01',
#  'BUFFRMINVEBM02',
#  'BUFFRMINVEBM03',
#  'BUFFRMINVEBM04',
#  'BUFFRMINVEBM05',
#  'BUFFRMINVEBM06',
#  'BUFFRMINVEBT01',
#  'BUFFRMINVEBT04',
#  'BUFFRMINVEBT05',
#  'BUFFRMINVEBT06',
#  'BUFFRMINVEBT07',
#  'BUFFRMINVEBT08',
#  'BUFFRMINVEBT09',
#  'BUFFRMINVEBT10',
#  'BUFFRMINVEBT11',
#  'BUFFRMINVEBT13',
#  'BUFFRMINVEBT14',
#  'BUFFRMINVEBT15',
#  'BUFFRMINVEBT16',
#  'BUFFRMINVEBT17',
#  'BUFFRMINVEBT20',
#  'BUFFRMINVEBT22',
#  'BUFFRMINVEBT23',
#  'BUFFRMINVEBT24',
#  'BUFFRMINVEBT25',
#  'BUFFRMINVEBT30',
#  'BUFFRMINVEBT31',
#  'BUFFRMINVEBT33',
#  'EFMOAqubug01',
#  'GWCAAquBug01',
#  'GWCAAquBug02',
#  'GWCAAquBug03',
#  'HEHOAqubug01',
#  'HOMEAquBug01',
#  'HOMEAquBug02',
#  'HOSPAqubug01',
#  'HOSPAqubug02',
#  'OZARRMINVECM01',
#  'OZARRMINVECM02',
#  'OZARRMINVECM03',
#  'OZARRMINVECM04',
#  'OZARRMINVECM05',
#  'OZARRMINVECM06',
#  'OZARRMINVECT01',
#  'OZARRMINVECT02',
#  'OZARRMINVECT03',
#  'OZARRMINVECT04',
#  'OZARRMINVECT07',
# ...

# %%
df["FishLocationID"] = df["FishLocationID"].astype(str)
sorted(df["FishLocationID"].unique())
# Out:
# ['BUFFRMFISHBM01',
#  'BUFFRMFISHBM02',
#  'BUFFRMFISHBM03',
#  'BUFFRMFISHBM04',
#  'BUFFRMFISHBM05',
#  'BUFFRMFISHBM06',
#  'BUFFRMFISHBT01',
#  'BUFFRMFISHBT04',
#  'BUFFRMFISHBT05',
#  'BUFFRMFISHBT06',
#  'BUFFRMFISHBT07',
#  'BUFFRMFISHBT08',
#  'BUFFRMFISHBT09',
#  'BUFFRMFISHBT10',
#  'BUFFRMFISHBT11',
#  'BUFFRMFISHBT12',
#  'BUFFRMFISHBT13',
#  'BUFFRMFISHBT14',
#  'BUFFRMFISHBT15',
#  'BUFFRMFISHBT16',
#  'BUFFRMFISHBT17',
#  'BUFFRMFISHBT20',
#  'BUFFRMFISHBT21',
#  'BUFFRMFISHBT22',
#  'BUFFRMFISHBT23',
#  'BUFFRMFISHBT24',
#  'BUFFRMFISHBT25',
#  'BUFFRMFISHBT28',
#  'BUFFRMFISHBT29',
#  'BUFFRMFISHBT30',
#  'BUFFRMFISHBT31',
#  'BUFFRMFISHBT32',
#  'BUFFRMFISHBT33',
#  'EFMOStfish01',
#  'GWCAStfish01',
#  'GWCAStfish02',
#  'GWCAStfish03',
#  'HEHOStfish01',
#  'HOMEShiner01lower',
#  'HOMEShiner01upper',
#  'HOSPStfish01',
#  'HOSPStfish02',
#  'OZARRMFISHCM01',
#  'OZARRMFISHCM02',
#  'OZARRMFISHCM03',
#  'OZARRMFISHCM04',
#  'OZARRMFISHCM05',
#  'OZARRMFISHCM06',
# ...

# %%
df.dtypes
# Out:
# ReachID              object
# InvertLocationID     object
# FishLocationID       object
# ParkCode             object
# ParkName             object
# Latitude            float64
# Longitude           float64
# Notes                object
# dtype: object

# %%
sorted(df["ParkCode"].unique())
# Out:
# ['BUFF',
#  'EFMO',
#  'GWCA',
#  'HEHO',
#  'HOME',
#  'HOSP',
#  'OZAR',
#  'PIPE',
#  'TAPR',
#  'WICR']

# %%
sorted(df["ParkName"].unique())
# Out:
# ['Buffalo National River',
#  'Effigy Mounds National Monument',
#  'George Washington Carver National Monument',
#  'Herbert Hoover National Historic Site',
#  'Homestead National Monument of America',
#  'Hot Springs National Park',
#  'Ozark National Scenic Riverways',
#  'Pipestone National Monument',
#  'Tallgrass Prairie National Preserve',
#  "Wilson's Creek National Battlefield"]

# %%
sorted(df["Latitude"].unique())
# Out:
# [np.float64(34.517),
#  np.float64(34.528),
#  np.float64(35.923),
#  np.float64(35.945),
#  np.float64(35.972),
#  np.float64(35.974),
#  np.float64(35.983),
#  np.float64(35.989),
#  np.float64(35.993),
#  np.float64(35.995),
#  np.float64(35.999),
#  np.float64(36.0),
#  np.float64(36.001),
#  np.float64(36.01),
#  np.float64(36.011),
#  np.float64(36.012),
#  np.float64(36.02),
#  np.float64(36.025),
#  np.float64(36.033),
#  np.float64(36.037),
#  np.float64(36.051),
#  np.float64(36.052),
#  np.float64(36.059),
#  np.float64(36.061),
#  np.float64(36.072),
#  np.float64(36.08),
#  np.float64(36.084),
#  np.float64(36.087),
#  np.float64(36.096),
#  np.float64(36.109),
#  np.float64(36.132),
#  np.float64(36.135),
#  np.float64(36.152),
#  np.float64(36.836),
#  np.float64(36.853),
#  np.float64(36.952),
#  np.float64(36.988),
#  np.float64(36.989),
#  np.float64(36.99),
#  np.float64(37.038),
#  np.float64(37.051),
#  np.float64(37.053),
#  np.float64(37.054),
# ...

# %%
sorted(df["Longitude"].unique())
# Out:
# [np.float64(-96.841),
#  np.float64(-96.835),
#  np.float64(-96.595),
#  np.float64(-96.594),
#  np.float64(-96.592),
#  np.float64(-96.591),
#  np.float64(-96.587),
#  np.float64(-96.586),
#  np.float64(-96.585),
#  np.float64(-96.584),
#  np.float64(-96.576),
#  np.float64(-96.573),
#  np.float64(-96.567),
#  np.float64(-96.565),
#  np.float64(-96.563),
#  np.float64(-96.561),
#  np.float64(-96.559),
#  np.float64(-96.557),
#  np.float64(-96.549),
#  np.float64(-96.536),
#  np.float64(-96.531),
#  np.float64(-96.505),
#  np.float64(-96.326),
#  np.float64(-96.324),
#  np.float64(-96.321),
#  np.float64(-96.319),
#  np.float64(-94.359),
#  np.float64(-94.356),
#  np.float64(-94.355),
#  np.float64(-93.42),
#  np.float64(-93.414),
#  np.float64(-93.403),
#  np.float64(-93.397),
#  np.float64(-93.395),
#  np.float64(-93.311),
#  np.float64(-93.222),
#  np.float64(-93.207),
#  np.float64(-93.135),
#  np.float64(-93.117),
#  np.float64(-93.112),
#  np.float64(-93.11),
# ...

# %%
df.dtypes
# Out:
# ReachID              object
# InvertLocationID     object
# FishLocationID       object
# ParkCode             object
# ParkName             object
# Latitude            float64
# Longitude           float64
# Notes                object
# dtype: object

# %%
df["Notes"] = df["Notes"].astype(str)
sorted(df["Notes"].unique())
# Out:
# ['BUFFT12 not sampled for Inverts but sampled for Fish',
#  'BUFFT21 not sampled for Inverts but sampled for Fish',
#  'BUFFT28 not sampled for Inverts but sampled for Fish',
#  'BUFFT29 not sampled for Inverts but sampled for Fish',
#  'BUFFT32 not sampled for Inverts but sampled for Fish',
#  'CURRT11 not sampled for Inverts but sampled for Fish',
#  'Fish Site from 2005-2018; Invert site 2005-present',
#  'PIPEABV01 not sampled for Inverts',
#  'PIPELOW01 not sampled for Inverts',
#  'TAPRLOW01 not sampled for Inverts',
#  'TAPRLOW02 not sampled for Inverts',
#  'TAPRLOW17 not sampled for Inverts',
#  'TAPRLOW22 not sampled for Inverts',
#  'TAPRLOW24 not sampled for Inverts',
#  'TAPRLOW34 not sampled for Inverts',
#  'TAPRMID01 not sampled for Inverts',
#  'TAPRMID02 not sampled for Inverts',
#  'TAPRMID04 not sampled for Inverts',
#  'TAPRMID05 not sampled for Inverts',
#  'TAPRMID10 not sampled for Inverts',
#  'TAPRMID12 not sampled for Inverts',
# ...
