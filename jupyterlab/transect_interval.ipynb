# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\GRowell\fish-data\raw_data\HTLN_Fish_TransectInterval.csv"
df = pd.read_csv(path)
print(df.head())
# Out:
#    Season      LocationID              EventID ChannelType  \
# 0    2006  BUFFRMFISHBM01  BUFFRMFISH2006MAY23        main
# 1    2006  BUFFRMFISHBM02  BUFFRMFISH2006MAY30        main
# 2    2006  BUFFRMFISHBM03  BUFFRMFISH2006JUN01        main
# 3    2006  BUFFRMFISHBM04  BUFFRMFISH2006JUN02        main
# 4    2006  BUFFRMFISHBM05  BUFFRMFISH2006JUN12        main
#
#    ChannelTypeSampledLength_m  NumberOfTransects  TransectSpacingInterval_m  \
# 0                       290.0                 11                       29.0
# 1                       440.0                 11                       44.0
# 2                       600.0                 11                       60.0
# 3                       620.0                 11                       62.0
# 4                       560.0                 11                       56.0
#
#   Comment
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df.dtypes
# Out:
# Season                          int64
# LocationID                     object
# EventID                        object
# ChannelType                    object
# ChannelTypeSampledLength_m    float64
# NumberOfTransects               int64
# TransectSpacingInterval_m     float64
# Comment                        object
# dtype: object

# %%
sorted(df['Season'].unique())
# Out:
# [np.int64(2006),
#  np.int64(2007),
#  np.int64(2008),
#  np.int64(2009),
#  np.int64(2010),
#  np.int64(2011),
#  np.int64(2012),
#  np.int64(2013),
#  np.int64(2014),
#  np.int64(2015),
#  np.int64(2016),
#  np.int64(2017),
#  np.int64(2018),
#  np.int64(2019),
#  np.int64(2020),
#  np.int64(2021),
#  np.int64(2022),
#  np.int64(2023),
#  np.int64(2024)]

# %%
sorted(df["LocationID"].unique())
# Out:
# ['BUFFRMFISHBM01',
#  'BUFFRMFISHBM02',
#  'BUFFRMFISHBM03',
#  'BUFFRMFISHBM04',
#  'BUFFRMFISHBM05',
#  'BUFFRMFISHBM06',
#  'BUFFRMFISHBT01',
#  'BUFFRMFISHBT03',
#  'BUFFRMFISHBT04',
#  'BUFFRMFISHBT05',
#  'BUFFRMFISHBT06',
#  'BUFFRMFISHBT07',
#  'BUFFRMFISHBT08',
#  'BUFFRMFISHBT09',
#  'BUFFRMFISHBT10',
#  'BUFFRMFISHBT11',
#  'BUFFRMFISHBT12',
#  'BUFFRMFISHBT13',
#  'BUFFRMFISHBT14',
#  'BUFFRMFISHBT15',
#  'BUFFRMFISHBT16',
#  'BUFFRMFISHBT17',
#  'BUFFRMFISHBT19',
#  'BUFFRMFISHBT20',
#  'BUFFRMFISHBT21',
#  'BUFFRMFISHBT22',
#  'BUFFRMFISHBT23',
#  'BUFFRMFISHBT24',
#  'BUFFRMFISHBT25',
#  'BUFFRMFISHBT27',
#  'BUFFRMFISHBT28',
#  'BUFFRMFISHBT29',
#  'BUFFRMFISHBT30',
#  'BUFFRMFISHBT31',
#  'BUFFRMFISHBT32',
#  'BUFFRMFISHBT33',
#  'EFMOStfish01',
#  'GWCAStfish01',
#  'GWCAStfish02',
#  'GWCAStfish03',
#  'HEHOStfish01',
#  'HOSPStfish01',
#  'HOSPStfish02',
#  'OZARRMFISHCM01',
#  'OZARRMFISHCM02',
#  'OZARRMFISHCM02_Shift',
#  'OZARRMFISHCM03',
# ...

# %%
sorted(df['EventID'].unique())
# Out:
# ['BUFFRMFISH2006JUN01',
#  'BUFFRMFISH2006JUN02',
#  'BUFFRMFISH2006JUN05',
#  'BUFFRMFISH2006JUN06',
#  'BUFFRMFISH2006JUN12',
#  'BUFFRMFISH2006MAY22',
#  'BUFFRMFISH2006MAY23',
#  'BUFFRMFISH2006MAY24',
#  'BUFFRMFISH2006MAY25',
#  'BUFFRMFISH2006MAY30',
#  'BUFFRMFISH2017Jun01',
#  'BUFFRMFISH2017Jun02',
#  'BUFFRMFISH2017Jun13',
#  'BUFFRMFISH2017Jun14',
#  'BUFFRMFISH2017Jun15',
#  'BUFFRMFISH2017Jun21',
#  'BUFFRMFISH2017Jun22',
#  'BUFFRMFISH2017May24',
#  'BUFFRMFISH2017May25',
#  'BUFFRMFISH2017May30',
#  'BUFFRMFISH2017May31',
#  'BUFFRMFISH2019Jun05',
#  'BUFFRMFISH2019Jun06',
#  'BUFFRMFISH2019Jun12',
#  'BUFFRMFISH2019Jun14',
#  'BUFFRMFISH2019Jun17',
#  'BUFFRMFISH2019Jun18',
#  'BUFFRMFISH2019Jun19',
#  'BUFFRMFISH2019Jun20',
#  'BUFFRMFISH2019May22',
#  'BUFFRMFISH2019May23',
#  'BUFFRMFISH2019May24',
#  'BUFFRMFISH2019May28',
#  'BUFFRMFISH2021Jun09',
#  'BUFFRMFISH2021Jun10',
#  'BUFFRMFISH2021Jun11',
#  'BUFFRMFISH2021Jun16',
#  'BUFFRMFISH2021May17',
# ...

# %%
df.dtypes
# Out:
# Season                          int64
# LocationID                     object
# EventID                        object
# ChannelType                    object
# ChannelTypeSampledLength_m    float64
# NumberOfTransects               int64
# TransectSpacingInterval_m     float64
# Comment                        object
# dtype: object

# %%
df["ChannelType"] = df["ChannelType"].astype(str)
sorted(df['ChannelType'].unique())
# Out:
# ['Backwater_main',
#  'Backwater_side',
#  'Main',
#  'Side channel',
#  'backwater_main',
#  'backwater_side',
#  'main',
#  'side channel']

# %%
cols = ['ChannelTypeSampledLength_m'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='ChannelTypeSampledLength_m')
# Out:
# array([[<Axes: title={'center': 'ChannelTypeSampledLength_m'}>]],
#       dtype=object)

# %%
cols = ['NumberOfTransects'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='NumberOfTransects')
# Out:
# array([[<Axes: title={'center': 'NumberOfTransects'}>]], dtype=object)

# %%
cols = ['TransectSpacingInterval_m'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='TransectSpacingInterval_m')
# Out:
# array([[<Axes: title={'center': 'TransectSpacingInterval_m'}>]],
#       dtype=object)

# %%
df["Comment"] = df["Comment"].astype(str)
sorted(df['Comment'].unique())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 df["Comments"] = df["Comment"].astype(str)
# ----> 2 sorted(df['Comment'].unique())
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
df["SampleLocation"] = df["SampleLocation"].astype(str)
sorted(df['SampleLocation'].unique())
# Out:
# ['L', 'R']

# %%
cols = ['RiparianCover_0to25_m'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='RiparianCover_0to25_m')
# Out:
# array([[<Axes: title={'center': 'RiparianCover_0to25_m'}>]], dtype=object)

# %%
cols = ['RiparianCover_26to50_m'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='RiparianCover_26to50_m')
# Out:
# array([[<Axes: title={'center': 'RiparianCover_26to50_m'}>]], dtype=object)

# %%
cols = ['RiparianCover_51to75_m'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='RiparianCover_51to75_m')
# Out:
# array([[<Axes: title={'center': 'RiparianCover_51to75_m'}>]], dtype=object)

# %%
cols = ['RiparianCover_76to100_m'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='RiparianCover_76to100_m')
# Out:
# array([[<Axes: title={'center': 'RiparianCover_76to100_m'}>]],
#       dtype=object)

# %%
df.dtypes
# Out:
# Season                                         int64
# LocationID                                    object
# EventID                                       object
# SiteNumber                                     int64
# ChannelType                                   object
# SampleLocation                                object
# RiparianCover_0to25_m                        float64
# RiparianCover_26to50_m                       float64
# RiparianCover_51to75_m                       float64
# RiparianCover_76to100_m                      float64
# RiparianCover_GT100_m                        float64
# StreamBankErosionCover                       float64
# StreamBankErosion_DaubenmireCoverMidpoint    float64
# dtype: object

# %%
cols = ['RiparianCover_GT100_m'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='RiparianCover_GT100_m')
# Out:
# array([[<Axes: title={'center': 'RiparianCover_GT100_m'}>]], dtype=object)

# %%
cols = ['StreamBankErosionCover'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='StreamBankErosionCover')
# Out:
# array([[<Axes: title={'center': 'StreamBankErosionCover'}>]], dtype=object)

# %%
cols = ['StreamBankErosion_DaubenmireCoverMidpoint'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='StreamBankErosion_DaubenmireCoverMidpoint')
# Out:
# array([[<Axes: title={'center': 'StreamBankErosion_DaubenmireCoverMidpoint'}>]],
#       dtype=object)
