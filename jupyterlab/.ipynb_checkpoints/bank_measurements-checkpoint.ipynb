# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\GRowell\fish-data\raw_data\HTLN_Fish_BankMeasurements.csv"
df = pd.read_csv(path)
print(df.head())
# Out:
#    Season      LocationID              EventID ChannelType  TransectNumber  \
# 0    2006  BUFFRMFISHBM01  BUFFRMFISH2006MAY23        main               1
# 1    2006  BUFFRMFISHBM01  BUFFRMFISH2006MAY23        main               1
# 2    2006  BUFFRMFISHBM01  BUFFRMFISH2006MAY23        main               2
# 3    2006  BUFFRMFISHBM01  BUFFRMFISH2006MAY23        main               2
# 4    2006  BUFFRMFISHBM01  BUFFRMFISH2006MAY23        main               3
#
#   SampleLocation  BankAngle  BankVegCover  BankHeight  BankSubstrate  \
# 0              L        3.0           2.0         5.0            2.0
# 1              R        3.0           1.0         5.0            2.0
# 2              L        3.0           4.0         5.0            2.0
# 3              R        1.0           1.0         2.0            2.0
# 4              L        3.0           1.0         5.0            2.0
#
#    LargeTrees  SmTreesShrubs  GrassForbes  BareRockSediment  Artificial  \
# ...

# %%
df.dtypes
# Out:
# Season                int64
# LocationID           object
# EventID              object
# ChannelType          object
# TransectNumber        int64
# SampleLocation       object
# BankAngle           float64
# BankVegCover        float64
# BankHeight          float64
# BankSubstrate       float64
# LargeTrees            int64
# SmTreesShrubs         int64
# GrassForbes           int64
# BareRockSediment      int64
# Artificial            int64
# Comment              object
# dtype: object

# %%
sorted(df['LocationID'].unique())
# Out:
# ['BUFFRMFISHBM01',
#  'BUFFRMFISHBM02',
#  'BUFFRMFISHBM03',
#  'BUFFRMFISHBM04',
#  'BUFFRMFISHBM05',
#  'BUFFRMFISHBM06',
#  'BUFFRMFISHBT01',
#  'BUFFRMFISHBT03',
#  'BUFFRMFISHBT04',
#  'BUFFRMFISHBT05',
#  'BUFFRMFISHBT06',
#  'BUFFRMFISHBT07',
#  'BUFFRMFISHBT08',
#  'BUFFRMFISHBT09',
#  'BUFFRMFISHBT10',
#  'BUFFRMFISHBT11',
#  'BUFFRMFISHBT12',
#  'BUFFRMFISHBT13',
#  'BUFFRMFISHBT14',
#  'BUFFRMFISHBT15',
#  'BUFFRMFISHBT16',
#  'BUFFRMFISHBT17',
#  'BUFFRMFISHBT19',
#  'BUFFRMFISHBT20',
#  'BUFFRMFISHBT21',
#  'BUFFRMFISHBT22',
#  'BUFFRMFISHBT23',
#  'BUFFRMFISHBT24',
#  'BUFFRMFISHBT25',
#  'BUFFRMFISHBT27',
#  'BUFFRMFISHBT28',
#  'BUFFRMFISHBT29',
#  'BUFFRMFISHBT30',
#  'BUFFRMFISHBT31',
#  'BUFFRMFISHBT32',
#  'BUFFRMFISHBT33',
#  'EFMOStfish01',
#  'GWCAStfish01',
#  'GWCAStfish02',
#  'GWCAStfish03',
#  'HEHOStfish01',
#  'HOSPStfish01',
#  'HOSPStfish02',
#  'OZARRMFISHCM01',
#  'OZARRMFISHCM02',
#  'OZARRMFISHCM02_Shift',
#  'OZARRMFISHCM03',
# ...

# %%
sorted(df['EventID'].unique())
# Out:
# ['BUFFRMFISH2006JUN01',
#  'BUFFRMFISH2006JUN02',
#  'BUFFRMFISH2006JUN05',
#  'BUFFRMFISH2006JUN06',
#  'BUFFRMFISH2006JUN12',
#  'BUFFRMFISH2006MAY22',
#  'BUFFRMFISH2006MAY23',
#  'BUFFRMFISH2006MAY24',
#  'BUFFRMFISH2006MAY25',
#  'BUFFRMFISH2006MAY30',
#  'BUFFRMFISH2017Jun01',
#  'BUFFRMFISH2017Jun02',
#  'BUFFRMFISH2017Jun13',
#  'BUFFRMFISH2017Jun14',
#  'BUFFRMFISH2017Jun15',
#  'BUFFRMFISH2017Jun21',
#  'BUFFRMFISH2017Jun22',
#  'BUFFRMFISH2017May24',
#  'BUFFRMFISH2017May25',
#  'BUFFRMFISH2017May30',
#  'BUFFRMFISH2017May31',
#  'BUFFRMFISH2019Jun05',
#  'BUFFRMFISH2019Jun06',
#  'BUFFRMFISH2019Jun12',
#  'BUFFRMFISH2019Jun14',
#  'BUFFRMFISH2019Jun17',
#  'BUFFRMFISH2019Jun18',
#  'BUFFRMFISH2019Jun19',
#  'BUFFRMFISH2019Jun20',
#  'BUFFRMFISH2019May22',
#  'BUFFRMFISH2019May23',
#  'BUFFRMFISH2019May24',
#  'BUFFRMFISH2019May28',
#  'BUFFRMFISH2021Jun09',
#  'BUFFRMFISH2021Jun10',
#  'BUFFRMFISH2021Jun11',
#  'BUFFRMFISH2021Jun16',
#  'BUFFRMFISH2021May17',
# ...

# %%
sorted(df["ChannelType"].unique())
# Out:
# ['Main', 'Side channel', 'main', 'side channel']

# %%
sorted(df["TransectNumber"].unique())
# Out:
# [np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9),
#  np.int64(10),
#  np.int64(11)]

# %%
sorted(df["SampleLocation"].unique())
# Out:
# ['L', 'R']

# %%
sorted(df["BankAngle"].unique())
# Out:
# [np.float64(1.0), np.float64(2.0), np.float64(3.0), np.float64(nan)]

# %%
sorted(df["BankVegCover"].unique())
# Out:
# [np.float64(1.0),
#  np.float64(2.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(nan)]

# %%
sorted(df["BankHeight"].unique())
# Out:
# [np.float64(1.0),
#  np.float64(2.0),
#  np.float64(3.0),
#  np.float64(4.0),
#  np.float64(5.0),
#  np.float64(nan)]

# %%
sorted(df["BankSubstrate"].unique())
# Out:
# [np.float64(1.0),
#  np.float64(2.0),
#  np.float64(5.0),
#  np.float64(8.0),
#  np.float64(10.0),
#  np.float64(nan)]

# %%
sorted(df["LargeTrees"].unique())
# Out:
# [np.int64(0), np.int64(1)]

# %%
sorted(df["SmTreesShrubs"].unique())
# Out:
# [np.int64(0), np.int64(1)]

# %%
sorted(df["GrassForbes"].unique())
# Out:
# [np.int64(0), np.int64(1)]

# %%
sorted(df["BareRockSediment"].unique())
# Out:
# [np.int64(0), np.int64(1)]

# %%
sorted(df["Artificial"].unique())
# Out:
# [np.int64(0), np.int64(1)]

# %%
df["Comment"] = df["Comment"].astype(str)
sorted(df["Comment"].unique())
# Out:
# ['.5 m gravel bar',
#  '.5m island',
#  '0.5 meter island',
#  '0.5m gravel bar',
#  '0.5m gravel island',
#  '0.6 meter island',
#  '1 m Gravel Bar',
#  '1 m gravel bar',
#  '1 m island',
#  '1 meter sand bar',
#  '1.0 m gravel bar',
#  '1.1m island',
#  '1.2 m gravel bar',
#  '1.2 meter island and 9.6 meter silt/sand bar',
#  '1.2 meter sand bar',
#  '1.3 meter gravel bar and 1.9 island',
#  '1.3m Gravel Bar',
#  '1.3m gravel bar',
#  '1.4 m gravel bar',
#  '1.4m gravel bar',
#  '1.4m gravel bar.',
#  '1.5 m Gravel Bar',
#  '1.5 m gravel bar',
#  '1.5 meter gravel bar',
#  '1.5 meter gravel bar on right bank',
#  '1.5 meter island',
#  '1.5m gravel bar',
#  '1.5m gravel bar.',
#  '1.5m island',
#  '1.6m gravel bar; bluff',
#  '1.7 m gravel bar',
#  '1.7 meter gravel bar',
#  '1.7m island',
#  '1.8m gravel bar.',
#  '1.9 m gravel bar',
#  '1.9m gravel bar',
#  '10 Meter Gravel Bar',
#  '10 m cobble bar',
#  '10 m gravel bar',
#  '10 m gravel island',
#  '10 meter sand/silt bar',
# ...
