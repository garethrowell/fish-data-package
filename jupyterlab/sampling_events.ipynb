# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\GRowell\fish-data\raw_data\HTLN_Fish_SamplingEvents.csv"
df = pd.read_csv(path)
print(df.head())
# Out:
#                EventID             PeriodID ParkCode ProjectCode  Season  \
# 0  BUFFRMFISH2006JUN01  BUFFRMFISH2006MAY22     BUFF      RMFISH    2006
# 1  BUFFRMFISH2006JUN02  BUFFRMFISH2006MAY22     BUFF      RMFISH    2006
# 2  BUFFRMFISH2006JUN05  BUFFRMFISH2006MAY22     BUFF      RMFISH    2006
# 3  BUFFRMFISH2006JUN06  BUFFRMFISH2006MAY22     BUFF      RMFISH    2006
# 4  BUFFRMFISH2006JUN12  BUFFRMFISH2006MAY22     BUFF      RMFISH    2006
#
#    StartDate    EndDate AdditionalComments
# 0   6/1/2006   6/1/2006                NaN
# 1   6/2/2006   6/2/2006                NaN
# 2   6/5/2006   6/5/2006                NaN
# 3   6/6/2006   6/6/2006                NaN
# 4  6/12/2006  6/12/2006                NaN

# %%
df.dtypes
# Out:
# EventID               object
# PeriodID              object
# ParkCode              object
# ProjectCode           object
# Season                 int64
# StartDate             object
# EndDate               object
# AdditionalComments    object
# dtype: object

# %%
sorted(df['EventID'].unique())
# Out:
# ['BUFFRMFISH2006JUN01',
#  'BUFFRMFISH2006JUN02',
#  'BUFFRMFISH2006JUN05',
#  'BUFFRMFISH2006JUN06',
#  'BUFFRMFISH2006JUN12',
#  'BUFFRMFISH2006MAY22',
#  'BUFFRMFISH2006MAY23',
#  'BUFFRMFISH2006MAY24',
#  'BUFFRMFISH2006MAY25',
#  'BUFFRMFISH2006MAY30',
#  'BUFFRMFISH2017Jun01',
#  'BUFFRMFISH2017Jun02',
#  'BUFFRMFISH2017Jun13',
#  'BUFFRMFISH2017Jun14',
#  'BUFFRMFISH2017Jun15',
#  'BUFFRMFISH2017Jun21',
#  'BUFFRMFISH2017Jun22',
#  'BUFFRMFISH2017May24',
#  'BUFFRMFISH2017May25',
#  'BUFFRMFISH2017May30',
#  'BUFFRMFISH2017May31',
#  'BUFFRMFISH2019Jun05',
#  'BUFFRMFISH2019Jun06',
#  'BUFFRMFISH2019Jun12',
#  'BUFFRMFISH2019Jun14',
#  'BUFFRMFISH2019Jun17',
#  'BUFFRMFISH2019Jun18',
#  'BUFFRMFISH2019Jun19',
#  'BUFFRMFISH2019Jun20',
#  'BUFFRMFISH2019May22',
#  'BUFFRMFISH2019May23',
#  'BUFFRMFISH2019May24',
#  'BUFFRMFISH2019May28',
#  'BUFFRMFISH2021Jun09',
#  'BUFFRMFISH2021Jun10',
#  'BUFFRMFISH2021Jun11',
#  'BUFFRMFISH2021Jun16',
#  'BUFFRMFISH2021May17',
# ...

# %%
df["InvertLocationID"] = df["InvertLocationID"].astype(str)
sorted(df["InvertLocationID"].unique())
# Out:
# ['BUFFRMINVEBM01',
#  'BUFFRMINVEBM02',
#  'BUFFRMINVEBM03',
#  'BUFFRMINVEBM04',
#  'BUFFRMINVEBM05',
#  'BUFFRMINVEBM06',
#  'BUFFRMINVEBT01',
#  'BUFFRMINVEBT04',
#  'BUFFRMINVEBT05',
#  'BUFFRMINVEBT06',
#  'BUFFRMINVEBT07',
#  'BUFFRMINVEBT08',
#  'BUFFRMINVEBT09',
#  'BUFFRMINVEBT10',
#  'BUFFRMINVEBT11',
#  'BUFFRMINVEBT13',
#  'BUFFRMINVEBT14',
#  'BUFFRMINVEBT15',
#  'BUFFRMINVEBT16',
#  'BUFFRMINVEBT17',
#  'BUFFRMINVEBT20',
#  'BUFFRMINVEBT22',
#  'BUFFRMINVEBT23',
#  'BUFFRMINVEBT24',
#  'BUFFRMINVEBT25',
#  'BUFFRMINVEBT30',
#  'BUFFRMINVEBT31',
#  'BUFFRMINVEBT33',
#  'EFMOAqubug01',
#  'GWCAAquBug01',
#  'GWCAAquBug02',
#  'GWCAAquBug03',
#  'HEHOAqubug01',
#  'HOMEAquBug01',
#  'HOMEAquBug02',
#  'HOSPAqubug01',
#  'HOSPAqubug02',
#  'OZARRMINVECM01',
#  'OZARRMINVECM02',
#  'OZARRMINVECM03',
#  'OZARRMINVECM04',
#  'OZARRMINVECM05',
#  'OZARRMINVECM06',
#  'OZARRMINVECT01',
#  'OZARRMINVECT02',
#  'OZARRMINVECT03',
#  'OZARRMINVECT04',
#  'OZARRMINVECT07',
# ...

# %%
sorted(df["PeriodID"].unique())
# Out:
# ['BUFFRMFISH2006MAY22',
#  'BUFFRMFISH2007Mar13',
#  'BUFFRMFISH2007Mar30',
#  'BUFFRMFISH2007May21',
#  'BUFFRMFISH2008May19',
#  'BUFFRMFISH2009May19',
#  'BUFFRMFISH2010May17',
#  'BUFFRMFISH2012May21',
#  'BUFFRMFISH2013May20',
#  'BUFFRMFISH2017May24',
#  'BUFFRMFISH2019May22',
#  'BUFFRMFISH2021May17',
#  'BUFFRMFISH2023May23',
#  'BUFFrmfish2015May22',
#  'EFMOStfish2008Jul09',
#  'EFMOStfish2014Aug13',
#  'EFMOStfish2017July18',
#  'EFMOStfish2023Jul19',
#  'GWCAStfish2006Jun28',
#  'GWCAStfish2007May02',
#  'GWCAStfish2010May05',
#  'GWCAStfish2013May01',
#  'GWCAStfish2016May02',
#  'GWCAStfish2019May06',
#  'GWCAStfish2022May02',
#  'HEHOStfish2008Jul08',
#  'HEHOStfish2011Jul11',
#  'HEHOStfish2014Aug12',
#  'HEHOStfish2017July18',
#  'HEHOStfish2021Jul26',
#  'HEHOStfish2022Jul05',
#  'HEHOStfish2023Jul17',
#  'HOMEShiner2004Sep13',
#  'HOMEShiner2006Aug31',
#  'HOMEShiner2008Aug27',
#  'HOMEShiner2011Sep20',
#  'HOMEShiner2015Sep03',
#  'HOMEShiner2017Sep07',
# ...

# %%
df.dtypes
# Out:
# EventID               object
# PeriodID              object
# ParkCode              object
# ProjectCode           object
# Season                 int64
# StartDate             object
# EndDate               object
# AdditionalComments    object
# dtype: object

# %%
sorted(df["ParkCode"].unique())
# Out:
# ['BUFF',
#  'EFMO',
#  'GWCA',
#  'HEHO',
#  'HOME',
#  'HOSP',
#  'OZAR',
#  'OZRS',
#  'PERI',
#  'PIPE',
#  'TAPR',
#  'WICR']

# %%
sorted(df["ProjectCode"].unique())
# Out:
# ['RMFISH', 'RMFish', 'SPRNGS', 'Shiner', 'Sprngs', 'Stfish', 'rmfish']

# %%
sorted(df["Season"].unique())
# Out:
# [np.int64(2001),
#  np.int64(2002),
#  np.int64(2003),
#  np.int64(2004),
#  np.int64(2005),
#  np.int64(2006),
#  np.int64(2007),
#  np.int64(2008),
#  np.int64(2009),
#  np.int64(2010),
#  np.int64(2011),
#  np.int64(2012),
#  np.int64(2013),
#  np.int64(2014),
#  np.int64(2015),
#  np.int64(2016),
#  np.int64(2017),
#  np.int64(2018),
#  np.int64(2019),
#  np.int64(2020),
#  np.int64(2021),
#  np.int64(2022),
#  np.int64(2023),
#  np.int64(2024)]

# %%
sorted(df["StartDate"].unique())
# Out:
# ['1/1/2020',
#  '10/1/2002',
#  '10/1/2007',
#  '10/1/2012',
#  '10/1/2014',
#  '10/10/2001',
#  '10/10/2007',
#  '10/10/2008',
#  '10/10/2012',
#  '10/10/2018',
#  '10/11/2001',
#  '10/11/2012',
#  '10/11/2018',
#  '10/12/2001',
#  '10/12/2007',
#  '10/12/2016',
#  '10/13/2001',
#  '10/13/2009',
#  '10/14/2009',
#  '10/15/2008',
#  '10/16/2007',
#  '10/16/2008',
#  '10/16/2009',
#  '10/16/2014',
#  '10/17/2007',
#  '10/17/2008',
#  '10/18/2006',
#  '10/18/2007',
#  '10/18/2012',
#  '10/19/2006',
#  '10/19/2009',
#  '10/2/2002',
#  '10/2/2006',
#  '10/2/2007',
#  '10/2/2012',
#  '10/2/2014',
#  '10/2/2018',
#  '10/20/2005',
#  '10/20/2006',
#  '10/20/2009',
#  '10/21/2009',
#  '10/23/2006',
#  '10/24/2006',
#  '10/25/2005',
#  '10/25/2006',
#  '10/26/2005',
#  '10/27/2005',
#  '10/27/2008',
#  '10/28/2005',
#  '10/29/2008',
#  '10/3/2002',
#  '10/3/2005',
#  '10/3/2006',
#  '10/3/2007',
#  '10/3/2012',
#  '10/3/2014',
#  '10/3/2018',
#  '10/4/2002',
#  '10/4/2004',
#  '10/4/2005',
# ...

# %%
df.dtypes
# Out:
# EventID               object
# PeriodID              object
# ParkCode              object
# ProjectCode           object
# Season                 int64
# StartDate             object
# EndDate               object
# AdditionalComments    object
# dtype: object

# %%
sorted(df["EndDate"].unique())
# Out:
# ['1/1/2020',
#  '10/1/2002',
#  '10/1/2012',
#  '10/1/2014',
#  '10/10/2001',
#  '10/10/2007',
#  '10/10/2008',
#  '10/10/2018',
#  '10/11/2001',
#  '10/11/2016',
#  '10/11/2018',
#  '10/12/2001',
#  '10/12/2016',
#  '10/13/2001',
#  '10/13/2009',
#  '10/13/2016',
#  '10/14/2009',
#  '10/15/2012',
#  '10/16/2007',
#  '10/16/2008',
#  '10/16/2009',
#  '10/16/2012',
#  '10/16/2014',
#  '10/16/2018',
#  '10/17/2007',
#  '10/17/2008',
#  '10/17/2012',
#  '10/18/2007',
#  '10/18/2012',
#  '10/19/2007',
#  '10/2/2002',
#  '10/2/2006',
#  '10/2/2007',
#  '10/2/2012',
#  '10/2/2014',
#  '10/2/2018',
#  '10/20/2005',
#  '10/20/2009',
#  '10/21/2009',
#  '10/23/2006',
#  '10/24/2006',
#  '10/25/2005',
#  '10/26/2005',
#  '10/26/2006',
#  '10/27/2005',
#  '10/28/2005',
#  '10/28/2008',
#  '10/29/2008',
#  '10/3/2002',
#  '10/3/2005',
#  '10/3/2006',
#  '10/3/2007',
#  '10/3/2012',
#  '10/3/2014',
#  '10/3/2018',
#  '10/30/2008',
#  '10/4/2002',
#  '10/4/2004',
#  '10/4/2005',
#  '10/4/2006',
# ...

# %%
df.dtypes
# Out:
# EventID               object
# PeriodID              object
# ParkCode              object
# ProjectCode           object
# Season                 int64
# StartDate             object
# EndDate               object
# AdditionalComments    object
# dtype: object

# %%
df["AdditionalComments"] = df["AdditionalComments"].astype(str)
sorted(df["AdditionalComments"].unique())
# Out:
# ['Above the Falls - a lot of filamentous algae present; difficult to get fish our of seine and in bucket. Lower site- pools had aquatic veg in center of channel, difficult to get fish out of seine.',
#  'All data and sites for BUFF 2019 is flagged due to repeated high rain and flood events. Diversity and abundance was low. Flag data in Fish Community and Individual Fish tables for all sites.',
#  'Awesome Day.',
#  'Bear Creek',
#  'Could not sample last ~20m due to deep pool',
#  'Current was sift - difficult to catch sculpins and darters from boat.',
#  'Did not take Ending measurement readings for Core 5 at JACKM01.',
#  'Habitat collected on 7/17/23, Fish collected on 7/18/2023',
#  'High flow event week prior. Debris about 4 feet up on bank. Fish community seems comparable to previous years.',
#  'Large amount of deposited sand and gravel from flooding in spring and again in Sept.',
#  'Log jam in reach - some fish excaped due to large amounts of woody debris.',
# ...
