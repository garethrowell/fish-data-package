# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\GRowell\fish-data\raw_data\HTLN_Fish_TransectInterval.csv"
df = pd.read_csv(path)
print(df.head())
# Out:
#    Season      LocationID              EventID ChannelType  \
# 0    2006  BUFFRMFISHBM01  BUFFRMFISH2006MAY23        main
# 1    2006  BUFFRMFISHBM02  BUFFRMFISH2006MAY30        main
# 2    2006  BUFFRMFISHBM03  BUFFRMFISH2006JUN01        main
# 3    2006  BUFFRMFISHBM04  BUFFRMFISH2006JUN02        main
# 4    2006  BUFFRMFISHBM05  BUFFRMFISH2006JUN12        main
#
#    ChannelTypeSampledLength_m  NumberOfTransects  TransectSpacingInterval_m  \
# 0                       290.0                 11                       29.0
# 1                       440.0                 11                       44.0
# 2                       600.0                 11                       60.0
# 3                       620.0                 11                       62.0
# 4                       560.0                 11                       56.0
#
#   Comment
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df.dtypes
# Out:
# Season                          int64
# LocationID                     object
# EventID                        object
# ChannelType                    object
# ChannelTypeSampledLength_m    float64
# NumberOfTransects               int64
# TransectSpacingInterval_m     float64
# Comment                        object
# dtype: object

# %%
sorted(df['Season'].unique())
# Out:
# [np.int64(2006),
#  np.int64(2007),
#  np.int64(2008),
#  np.int64(2009),
#  np.int64(2010),
#  np.int64(2011),
#  np.int64(2012),
#  np.int64(2013),
#  np.int64(2014),
#  np.int64(2015),
#  np.int64(2016),
#  np.int64(2017),
#  np.int64(2018),
#  np.int64(2019),
#  np.int64(2020),
#  np.int64(2021),
#  np.int64(2022),
#  np.int64(2023),
#  np.int64(2024)]

# %%
sorted(df["LocationID"].unique())
# Out:
# ['BUFFRMFISHBM01',
#  'BUFFRMFISHBM02',
#  'BUFFRMFISHBM03',
#  'BUFFRMFISHBM04',
#  'BUFFRMFISHBM05',
#  'BUFFRMFISHBM06',
#  'BUFFRMFISHBT01',
#  'BUFFRMFISHBT03',
#  'BUFFRMFISHBT04',
#  'BUFFRMFISHBT05',
#  'BUFFRMFISHBT06',
#  'BUFFRMFISHBT07',
#  'BUFFRMFISHBT08',
#  'BUFFRMFISHBT09',
#  'BUFFRMFISHBT10',
#  'BUFFRMFISHBT11',
#  'BUFFRMFISHBT12',
#  'BUFFRMFISHBT13',
#  'BUFFRMFISHBT14',
#  'BUFFRMFISHBT15',
#  'BUFFRMFISHBT16',
#  'BUFFRMFISHBT17',
#  'BUFFRMFISHBT19',
#  'BUFFRMFISHBT20',
#  'BUFFRMFISHBT21',
#  'BUFFRMFISHBT22',
#  'BUFFRMFISHBT23',
#  'BUFFRMFISHBT24',
#  'BUFFRMFISHBT25',
#  'BUFFRMFISHBT27',
#  'BUFFRMFISHBT28',
#  'BUFFRMFISHBT29',
#  'BUFFRMFISHBT30',
#  'BUFFRMFISHBT31',
#  'BUFFRMFISHBT32',
#  'BUFFRMFISHBT33',
#  'EFMOStfish01',
#  'GWCAStfish01',
#  'GWCAStfish02',
#  'GWCAStfish03',
#  'HEHOStfish01',
#  'HOSPStfish01',
#  'HOSPStfish02',
#  'OZARRMFISHCM01',
#  'OZARRMFISHCM02',
#  'OZARRMFISHCM02_Shift',
#  'OZARRMFISHCM03',
#  'OZARRMFISHCM03_Shift',
#  'OZARRMFISHCM04',
#  'OZARRMFISHCM05',
#  'OZARRMFISHCM06',
#  'OZARRMFISHCM06_Shift',
#  'OZARRMFISHCT01',
#  'OZARRMFISHCT02',
#  'OZARRMFISHCT03',
#  'OZARRMFISHCT04',
#  'OZARRMFISHCT06',
#  'OZARRMFISHCT07',
#  'OZARRMFISHCT08',
#  'OZARRMFISHCT09',
#  'OZARRMFISHCT11',
#  'OZARRMFISHCT12',
#  'OZARRMFISHCT13',
#  'OZARRMFISHCT14',
#  'OZARRMFISHCT15',
#  'OZARRMFISHCT16',
#  'OZARRMFISHJM01',
#  'OZARRMFISHJM02',
#  'OZARRMFISHJM03',
#  'OZARRMFISHJM03_Shift',
#  'OZARRMFISHJT01',
#  'OZARRMFISHJT02',
#  'OZARRMFISHJT03',
#  'OZRSSPRNGSSITE01',
#  'OZRSSPRNGSSITE02',
#  'OZRSSPRNGSSITE03',
#  'OZRSSPRNGSSITE04',
#  'OZRSSPRNGSSITE05',
#  'OZRSSPRNGSSITE06',
#  'OZRSSPRNGSSITE07',
#  'PERIStfish01',
#  'WICRStfish01',
#  'WICRStfish02',
#  'WICRStfish03']

# %%
sorted(df['EventID'].unique())
# Out:
# ['BUFFRMFISH2006JUN01',
#  'BUFFRMFISH2006JUN02',
#  'BUFFRMFISH2006JUN05',
#  'BUFFRMFISH2006JUN06',
#  'BUFFRMFISH2006JUN12',
#  'BUFFRMFISH2006MAY22',
#  'BUFFRMFISH2006MAY23',
#  'BUFFRMFISH2006MAY24',
#  'BUFFRMFISH2006MAY25',
#  'BUFFRMFISH2006MAY30',
#  'BUFFRMFISH2017Jun01',
#  'BUFFRMFISH2017Jun02',
#  'BUFFRMFISH2017Jun13',
#  'BUFFRMFISH2017Jun14',
#  'BUFFRMFISH2017Jun15',
#  'BUFFRMFISH2017Jun21',
#  'BUFFRMFISH2017Jun22',
#  'BUFFRMFISH2017May24',
#  'BUFFRMFISH2017May25',
#  'BUFFRMFISH2017May30',
#  'BUFFRMFISH2017May31',
#  'BUFFRMFISH2019Jun05',
#  'BUFFRMFISH2019Jun06',
#  'BUFFRMFISH2019Jun12',
#  'BUFFRMFISH2019Jun14',
#  'BUFFRMFISH2019Jun17',
#  'BUFFRMFISH2019Jun18',
#  'BUFFRMFISH2019Jun19',
#  'BUFFRMFISH2019Jun20',
#  'BUFFRMFISH2019May22',
#  'BUFFRMFISH2019May23',
#  'BUFFRMFISH2019May24',
#  'BUFFRMFISH2019May28',
#  'BUFFRMFISH2021Jun09',
#  'BUFFRMFISH2021Jun10',
#  'BUFFRMFISH2021Jun11',
#  'BUFFRMFISH2021Jun16',
#  'BUFFRMFISH2021May17',
#  'BUFFRMFISH2021May18',
#  'BUFFRMFISH2021May24',
#  'BUFFRMFISH2023Jun01',
#  'BUFFRMFISH2023Jun02',
#  'BUFFRMFISH2023Jun06',
#  'BUFFRMFISH2023Jun07',
#  'BUFFRMFISH2023Jun14',
#  'BUFFRMFISH2023May23',
#  'BUFFRMFISH2023May24',
#  'BUFFRMFISH2023May25',
#  'BUFFRMFISH2023May26',
#  'BUFFRMFISH2023May30',
#  'BUFFRMFISH2023May31',
#  'BUFFRMFish2007Jun01',
#  'BUFFRMFish2007Jun04',
#  'BUFFRMFish2007Jun05',
#  'BUFFRMFish2007Jun06',
#  'BUFFRMFish2007Jun20',
#  'BUFFRMFish2007May21',
#  'BUFFRMFish2007May22',
#  'BUFFRMFish2007May23',
#  'BUFFRMFish2007May25',
#  'BUFFRMFish2007May29',
#  'BUFFRMFish2007May30',
#  'BUFFRMFish2007May31',
#  'BUFFRMFish2008Jun03',
#  'BUFFRMFish2008Jun04',
#  'BUFFRMFish2008Jun05',
#  'BUFFRMFish2008Jun18',
#  'BUFFRMFish2008May19',
#  'BUFFRMFish2008May20',
#  'BUFFRMFish2008May21',
#  'BUFFRMFish2008May22',
#  'BUFFRMFish2008May23',
#  'BUFFRMFish2008May27',
#  'BUFFRMFish2008May28',
#  'BUFFRMFish2009Jun03',
#  'BUFFRMFish2009Jun08',
#  'BUFFRMFish2009Jun09',
#  'BUFFRMFish2009Jun10',
#  'BUFFRMFish2009May19',
#  'BUFFRMFish2009May20',
#  'BUFFRMFish2009May21',
#  'BUFFRMFish2009May26',
#  'BUFFRMFish2009May27',
#  'BUFFRMFish2009May28',
#  'BUFFRMFish2010Jun01',
#  'BUFFRMFish2010Jun02',
#  'BUFFRMFish2010Jun03',
#  'BUFFRMFish2010Jun08',
#  'BUFFRMFish2010Jun09',
#  'BUFFRMFish2010Jun10',
#  'BUFFRMFish2010Jun11',
#  'BUFFRMFish2010Jun23',
#  'BUFFRMFish2010May17',
#  'BUFFRMFish2010May18',
#  'BUFFRMFish2010May26',
#  'BUFFRMFish2010May27',
#  'BUFFRMFish2012May21',
#  'BUFFRMFish2012May22',
#  'BUFFRMFish2013Jun06',
#  'BUFFRMFish2013Jun10',
#  'BUFFRMFish2013Jun11',
#  'BUFFRMFish2013Jun12',
#  'BUFFRMFish2013Jun17',
#  'BUFFRMFish2013Jun18',
#  'BUFFRMFish2013Jun19',
#  'BUFFRMFish2013May20',
#  'BUFFRMFish2013May21',
#  'BUFFRMFish2013May28',
#  'BUFFRMFish2013May29',
#  'BUFFrmfish2015Jul01',
#  'BUFFrmfish2015Jun03',
#  'BUFFrmfish2015Jun04',
#  'BUFFrmfish2015Jun05',
#  'BUFFrmfish2015Jun09',
#  'BUFFrmfish2015Jun10',
#  'BUFFrmfish2015Jun15',
#  'BUFFrmfish2015Jun30',
#  'BUFFrmfish2015May22',
#  'BUFFrmfish2015May28',
#  'BUFFrmfish2015May29',
#  'EFMOStfish2008Jul09',
#  'EFMOStfish2014Aug13',
#  'EFMOStfish2017Jul18',
#  'EFMOStfish2023Jul19',
#  'GWCAStfish2006Jun28',
#  'GWCAStfish2007May02',
#  'GWCAStfish2010May05',
#  'GWCAStfish2013May01',
#  'GWCAStfish2016May02',
#  'GWCAStfish2019May06',
#  'GWCAStfish2022May03',
#  'GWCAStfish2022May09',
#  'HEHOStfish2008Jul08',
#  'HEHOStfish2011Jul11',
#  'HEHOStfish2014Aug12',
#  'HEHOStfish2017Jul18',
#  'HEHOStfish2021Jul26',
#  'HEHOStfish2022Jul05',
#  'HEHOStfish2023Jul17',
#  'HOSPStfish2009Jun16',
#  'HOSPStfish2012Jul10',
#  'HOSPStfish2015Jul07',
#  'HOSPStfish2018Jul09',
#  'HOSPStfish2018Jul10',
#  'HOSPStfish2024Jul16',
#  'HOSPStfish2024Jul17',
#  'OZARRMFISH2006OCT02',
#  'OZARRMFISH2006OCT03',
#  'OZARRMFISH2006OCT04',
#  'OZARRMFISH2006OCT05',
#  'OZARRMFISH2006OCT06',
#  'OZARRMFISH2006OCT18',
#  'OZARRMFISH2006OCT19',
#  'OZARRMFISH2006OCT20',
#  'OZARRMFISH2006OCT23',
#  'OZARRMFISH2006OCT24',
#  'OZARRMFISH2006OCT25',
#  'OZARRMFISH2010OCT05',
#  'OZARRMFISH2010OCT06',
#  'OZARRMFISH2014Oct09',
#  'OZARRMFISH2014Oct16',
#  'OZARRMFISH2014Sep22',
#  'OZARRMFISH2014Sep24',
#  'OZARRMFISH2014Sep25',
#  'OZARRMFISH2018Oct02',
#  'OZARRMFISH2018Oct03',
#  'OZARRMFISH2018Oct09',
#  'OZARRMFISH2018Oct10',
#  'OZARRMFISH2018Oct11',
#  'OZARRMFISH2018Sep18',
#  'OZARRMFISH2018Sep19',
#  'OZARRMFISH2018Sep20',
#  'OZARRMFISH2018Sep21',
#  'OZARRMFISH2018Sep25',
#  'OZARRMFISH2018Sep26',
#  'OZARRMFISH2018Sep27',
#  'OZARRMFISH2018Sep28',
#  'OZARRMFISH2022Aug29',
#  'OZARRMFISH2022Aug30',
#  'OZARRMFISH2022Aug31',
#  'OZARRMFISH2022Sep01',
#  'OZARRMFISH2022Sep02',
#  'OZARRMFISH2022Sep06',
#  'OZARRMFISH2022Sep07',
#  'OZARRMFISH2022Sep08',
#  'OZARRMFISH2022Sep09',
#  'OZARRMFISH2022Sep12',
#  'OZARRMFISH2022Sep13',
#  'OZARRMFISH2022Sep22',
#  'OZARRMFISH2024Aug26',
#  'OZARRMFISH2024Aug28',
#  'OZARRMFISH2024Aug29',
#  'OZARRMFISH2024Aug30',
#  'OZARRMFISH2024Sep03',
#  'OZARRMFISH2024Sep04',
#  'OZARRMFISH2024Sep05',
#  'OZARRMFISH2024Sep06',
#  'OZARRMFISH2024Sep09',
#  'OZARRMFISH2024Sep10',
#  'OZARRMFISH2024Sep11',
#  'OZARRMFISH2024Sep12',
#  'OZARRMFish2007Oct01',
#  'OZARRMFish2007Oct02',
#  'OZARRMFish2007Oct03',
#  'OZARRMFish2007Oct04',
#  'OZARRMFish2007Oct05',
#  'OZARRMFish2007Oct09',
#  'OZARRMFish2007Oct10',
#  'OZARRMFish2007Oct12',
#  'OZARRMFish2007Oct16',
#  'OZARRMFish2007Oct17',
#  'OZARRMFish2007Oct18',
#  'OZARRMFish2008Oct06',
#  'OZARRMFish2008Oct07',
#  'OZARRMFish2008Oct08',
#  'OZARRMFish2008Oct09',
#  'OZARRMFish2008Oct10',
#  'OZARRMFish2008Oct15',
#  'OZARRMFish2008Oct16',
#  'OZARRMFish2008Oct17',
#  'OZARRMFish2008Oct27',
#  'OZARRMFish2008Oct29',
#  'OZARRMFish2009Oct05',
#  'OZARRMFish2009Oct06',
#  'OZARRMFish2009Oct07',
#  'OZARRMFish2009Oct08',
#  'OZARRMFish2009Oct13',
#  'OZARRMFish2009Oct14',
#  'OZARRMFish2009Oct16',
#  'OZARRMFish2009Oct19',
#  'OZARRMFish2009Oct20',
#  'OZARRMFish2009Oct21',
#  'OZARRMFish2012Oct01',
#  'OZARRMFish2012Oct02',
#  'OZARRMFish2012Oct03',
#  'OZARRMFish2012Oct09',
#  'OZARRMFish2012Oct10',
#  'OZARRMFish2012Oct11',
#  'OZARRMFish2012Oct18',
#  'OZARRMFish2012Sep24',
#  'OZARRMFish2012Sep25',
#  'OZARRMFish2012Sep26',
#  'OZARRMFish2012Sep27',
#  'OZARRMFish2014Oct01',
#  'OZARRMFish2014Oct02',
#  'OZARRMFish2014Oct03',
#  'OZARRMFish2014Oct07',
#  'OZARRMFish2014Oct08',
#  'OZARRMFish2014Sep23',
#  'OZARRMFish2016Oct04',
#  'OZARRMFish2016Oct05',
#  'OZARRMFish2016Oct06',
#  'OZARRMFish2016Oct12',
#  'OZARRMFish2016Sep19',
#  'OZARRMFish2016Sep20',
#  'OZARRMFish2016Sep21',
#  'OZARRMFish2016Sep22',
#  'OZARRMFish2016Sep27',
#  'OZARRMFish2016Sep28',
#  'OZARRMFish2016Sep29',
#  'OZRSSPRNGS2007Aug01',
#  'OZRSSPRNGS2007JUL23',
#  'OZRSSPRNGS2007Jul24',
#  'OZRSSPRNGS2007Jul25',
#  'OZRSSPRNGS2007Jul30',
#  'OZRSSPRNGS2007Jul31',
#  'OZRSSPRNGS2008Jul21',
#  'OZRSSPRNGS2008Jul22',
#  'OZRSSPRNGS2008Jul23',
#  'OZRSSPRNGS2008Jul24',
#  'OZRSSPRNGS2008Jul25',
#  'OZRSSPRNGS2009Aug25',
#  'OZRSSPRNGS2009Jul27',
#  'OZRSSPRNGS2009Jul28',
#  'OZRSSPRNGS2009Jul29',
#  'OZRSSPRNGS2009Jul30',
#  'OZRSSPRNGS2010Jul26',
#  'OZRSSPRNGS2010Jul28',
#  'OZRSSPRNGS2010Jul29',
#  'OZRSSPRNGS2011Jul25',
#  'OZRSSPRNGS2011Jul26',
#  'OZRSSPRNGS2011Jul27',
#  'OZRSSPRNGS2011Jul28',
#  'OZRSSPRNGS2011Jul29',
#  'OZRSSPRNGS2012Jul23',
#  'OZRSSPRNGS2012Jul24',
#  'OZRSSPRNGS2012Jul25',
#  'OZRSSPRNGS2012Jul26',
#  'OZRSSPRNGS2013Aug16',
#  'OZRSSPRNGS2013Aug30',
#  'OZRSSPRNGS2013Jul29',
#  'OZRSSPRNGS2013Sep04',
#  'OZRSSPRNGS2013Sep13',
#  'OZRSSPRNGS2013Sep16',
#  'OZRSSPRNGS2014JUL31',
#  'OZRSSPRNGS2014Jul28',
#  'OZRSSPRNGS2014Jul29',
#  'OZRSSPRNGS2014Jul30',
#  'OZRSSPRNGS2015Aug06',
#  'OZRSSPRNGS2015Jul27',
#  'OZRSSPRNGS2015Jul28',
#  'OZRSSPRNGS2015Jul29',
#  'OZRSSPRNGS2016Jul25',
#  'OZRSSPRNGS2016Jul27',
#  'OZRSSPRNGS2016Jul28',
#  'OZRSSPRNGS2017Jul24',
#  'OZRSSPRNGS2017Jul25',
#  'OZRSSPRNGS2017Jul26',
#  'OZRSSPRNGS2017Jul27',
#  'OZRSSPRNGS2018Jul23',
#  'OZRSSPRNGS2018Jul24',
#  'OZRSSPRNGS2018Jul25',
#  'OZRSSPRNGS2018Jul26',
#  'OZRSSprngs2019Jul29',
#  'OZRSSprngs2019Jul30',
#  'OZRSSprngs2019Jul31',
#  'OZRSSprngs2019Sep05',
#  'OZRSSprngs2020Aug03',
#  'OZRSSprngs2020Jul29',
#  'OZRSSprngs2021Aug03',
#  'OZRSSprngs2021Aug05',
#  'OZRSSprngs2022Aug03',
#  'OZRSSprngs2022Jul27',
#  'OZRSSprngs2022Jul28',
#  'OZRSSprngs2023Aug01',
#  'OZRSSprngs2023Aug02',
#  'OZRSSprngs2024Jul29',
#  'OZRSSprngs2024Jul30',
#  'PERIStfish2009May01',
#  'PERIStfish2012May02',
#  'PERIStfish2015May12',
#  'PERIStfish2018May10',
#  'PERIStfish2021May06',
#  'PERIStfish2024May15',
#  'WICRStfish2006Jun15',
#  'WICRStfish2007May09',
#  'WICRStfish2010May03',
#  'WICRStfish2013May06',
#  'WICRStfish2016May04',
#  'WICRStfish2019Jun03',
#  'WICRStfish2019Jun11',
#  'WICRStfish2022Jun02',
#  'WICRStfish2022Jun09',
#  'WICRStfish2022Jun14']

# %%
df["ChannelType"] = df["ChannelType"].astype(str)
sorted(df['ChannelType'].unique())
# Out:
# ['Backwater_main',
#  'Backwater_side',
#  'Main',
#  'Side channel',
#  'backwater_main',
#  'backwater_side',
#  'main',
#  'side channel']

# %%
cols = ['ChannelTypeSampledLength_m'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='ChannelTypeSampledLength_m')
# Out:
# array([[<Axes: title={'center': 'ChannelTypeSampledLength_m'}>]],
#       dtype=object)

# %%
cols = ['NumberOfTransects'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='NumberOfTransects')
# Out:
# array([[<Axes: title={'center': 'NumberOfTransects'}>]], dtype=object)

# %%
cols = ['TransectSpacingInterval_m'] 
df2 = df[(df[cols] > 0)]
df2.hist(column='TransectSpacingInterval_m')
# Out:
# array([[<Axes: title={'center': 'TransectSpacingInterval_m'}>]],
#       dtype=object)

# %%
df["Comment"] = df["Comment"].astype(str)
sorted(df['Comment'].unique())
# Out:
# ['>200 means Over 200 cm depth',
#  'BW length not recorded',
#  'Backwater 1, L=45.4, TL=22.7; Backwater 2, L=33.5, TL=16.75',
#  'GPS waypoint off by 1 transect',
#  'GPS waypoint off. Only sampled half of site',
#  'Hit the end of site before gathering data for transects 10 and 11',
#  'Length not recorded in field',
#  'Only one transect sampled due to fallen tree',
#  'Only sampled transects 5-9 for fish.',
#  'Only took 10 transects; Transect 10 at newly shifted upper boundary flag.',
#  'Side channel is on river left.',
#  'Stopped short by two transects based on GPS location',
#  'Stream is up and very turbid',
#  'Transect 10 is 13m downstream of reach end.',
#  'Transect 11 started 20m upstream. Last transect (11) ended where transect 2 typically located.',
#  'Transect 11 was 36m short of upper fish reach.',
#  'Transect 3 not sampled (bridge construction); Transect 5 R c ould not be sampled due to bridge construction.',
#  'Transects were spaced every 30m instead of 24m due to incorrect reach length in database.',
#  'Upper (River Right, L=122, TL=61); Lower (River Left, L=67, TL=33)',
#  'Upper (River Right, L=220 TL=110); Lower (River Left, L=127, TL=64)',
#  'Upper (River Right, L=25, TL=12); Lower (River Left, L=42, TL=21)',
#  'Upper (River Right, L=45 TL=22.5); Lower (River Left, L=45 TL=22.5)',
#  'Upper (River Right, L=83 TL=41.5); Lower (River Left, L=140, TL=70)',
#  'nan',
#  'spacing interval not on field sheets',
#  'stopped at transect 10, 6 m past fish site.']
